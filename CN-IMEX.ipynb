# %% [markdown]
# # 3.2 Incompressible Navier-Stokes equations
#
# As in [the whetting the appetite demo](../wta/navierstokes.ipynb) we consider the unsteady Navier Stokes equations
#
# Find $(u,p):[0,T] \to (H_{0,D}^1)^d \times L^2$, s.t.
#
# \begin{align*}
# \int_{\Omega} \partial_t u \cdot v + \int_{\Omega} \nu \nabla u \nabla v + u \cdot \nabla u v - \int_{\Omega} \operatorname{div}(v) p &= \int f v  && \forall v \in (H_{0,D}^1)^d, \\
# - \int_{\Omega} \operatorname{div}(u) q &= 0 && \forall q \in L^2, \\
# \quad u(t=0) & = u_0
# \end{align*}

# %% [markdown]
# ### Schäfer-Turek benchmark
# We consider the benchmark setup of from http://www.featflow.de/en/benchmarks/cfdbenchmarking/flow/dfg_benchmark2_re100.html . The geometry is a 2D channel with a circular obstacle which is positioned (only slightly) off the center of the channel. The geometry:
#
# ![title](geometry.png)
#
# The viscosity is set to $\nu = 10^{-3}$.

# %%
# import libarries, define geometry and generate mesh
from ngsolve import *
from ngsolve.webgui import Draw
from netgen.occ import *
from netgen.webgui import Draw as DrawGeo
from math import pi

maxh  = 0.2
mesh = Mesh(unit_square.GenerateMesh(maxh=maxh))
h = specialcf.mesh_size
n = specialcf.normal

# %%
nu = 0.1
dt = 0.001
gammau = 0.001

# %%
# dirichlet="left|right|bottom|top"

# %%
tstart = 0.0 
t = Parameter(tstart)
u1 =  CoefficientFunction(t*t)
u_t = u1.Diff(t)
u_t(mesh(0.0))
# Out:
# 0.0

# %%
u_exact = CoefficientFunction((cos(t)*(2*sin(pi*x)**2*y*(1-y)*(1-2*y)),
                          cos(t)*(-pi*sin(2*pi*x)*y**2*(1-y)**2 ) ) )
p_exact = CoefficientFunction(cos(t)*sin(pi*x)*cos(pi*y) )

# %%
div_sol = u_exact[0].Diff(x) + u_exact[1].Diff(y) 
#div_sol(mesh(0.4,0.4))
div_square_L2 = Integrate(div_sol**2,mesh,order=12)
print("div_square_L2 = ", div_square_L2)
# Out:
# div_square_L2 =  4.8598484727884536e-33

# %%
rhs = CoefficientFunction(( u_exact[0].Diff(t) + (u_exact[0]*u_exact[0].Diff(x) + u_exact[1]*u_exact[0].Diff(y)) 
                           - nu* ( u_exact[0].Diff(x).Diff(x) + u_exact[0].Diff(y).Diff(y) ) +  p_exact.Diff(x) ,
                           u_exact[1].Diff(t) + (u_exact[0]*u_exact[1].Diff(x) + u_exact[1]*u_exact[1].Diff(y)) 
                           - nu* ( u_exact[1].Diff(x).Diff(x) + u_exact[1].Diff(y).Diff(y) ) +  p_exact.Diff(y)
                          ) )

# %%
mean_pressure = Integrate(p_exact,mesh,order=12)
print("mean pressure = ", mean_pressure)
# Out:
# mean pressure =  5.0306980803327406e-17

# %%
#DrawGeo (shape)
Draw (mesh)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %% [markdown]
# Viscosity:

# %% [markdown]
# ### Taylor-Hood velocity-pressure pair
#
# We use a Taylor-Hood discretization of degree $k$. The finite element space for the (vectorial) velocity $\mathbf{u}$ and the pressure $p$ are:
#
# \begin{align}
# \mathbf{u} \in \mathbf{V} &= \{ v \in H^1(\Omega) | v|_T \in \mathcal{P}^k(T) \}^2 \\
# p \in Q &= \{ q \in H^1(\Omega) | q|_T \in \mathcal{P}^{k-1}(T) \}
# \end{align}

# %%
k = 2
V1 = H1(mesh,order=1, dirichlet="left|right|bottom|top") 
V = VectorH1(mesh,order=k, dirichlet="left|right|bottom|top")
Q = H1(mesh,order=k)
L = NumberSpace(mesh)
X = V*Q*L

# %% [markdown]
# The `VectorH1` is the product space of two `H1` spaces with convenience operators for identity, `grad`(`Grad`) and `div`.

# %% [markdown]
# ### Stokes problem for initial values
# Find $\mathbf{u} \in \mathbf{V}$, $p \in Q$ so that
#
# \begin{align}
# \int_{\Omega} \nu \nabla \mathbf{u} : \nabla \mathbf{v} - \int_{\Omega} \operatorname{div}(\mathbf{v}) p &= \int \mathbf{f}  \cdot \mathbf{v}  && \forall \mathbf{v} \in \mathbf{V}, \\- \int_{\Omega} \operatorname{div}(\mathbf{u}) q &= 0 && \forall q \in Q,
# \end{align}
#
# with boundary conditions:
#
#  * the inflow boundary data ('inlet') with mean value $1$
#
# \begin{align}
# u_x(0,y) &= 6 y(0.41-y)/(0.41)^2, \quad \int_{0}^{0.41} u_x(0,y) dy = 1 \\
# u_y(0,y) &= 0
# \end{align}
#
#  * "do-nothing" boundary conditions on the ouflow ('outlet') and
#  * homogeneous Dirichlet conditions on all other boundaries ('wall').

# %%
gfu = GridFunction(X)
(u,p,lam), (v,q,mu) = X.TnT() 

u_0 = GridFunction(X)
u_1 = GridFunction(X)
ustar = GridFunction(X)
dustar = GridFunction(X)

# Set initial values using L2-projection
t.Set(0.0*dt)

mmass = BilinearForm(X)
mmass += InnerProduct(u,v)*dx
mmass.Assemble()
invm = mmass.mat.Inverse(X.FreeDofs())

for i,ui in zip(range(2),[u_0,u_1]):
    t.Set(i*dt)
    fm = LinearForm(X)   
    fm += InnerProduct( u_exact , v) * dx
    fm.Assemble()
    ui.vec.data = invm * fm.vec

Draw(u_0.components[0] ,mesh,"u0")
Draw(u_1.components[0] ,mesh,"u1")

velocity, pressure, meanp = gfu.components
# parabolic inflow at bc=1:
#uin = CoefficientFunction((1.5*4*y*(0.41-y)/(0.41*0.41),0))
#velocity.Set(uin, definedon=mesh.Boundaries("inlet"))

#Draw(velocity,mesh,"u")
#Draw(pressure,mesh,"p")

#Draw(u_exact,mesh,"u-exact")
#Draw( p_exact,mesh,"p-exact")
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…

# %%
beta_norm = GridFunction(V1)
beta_norm.Set(sqrt(InnerProduct(u_0.components[0],u_0.components[0] )) )
print( max(beta_norm.vec.FV().NumPy()[:]))
Draw(beta_norm ,mesh,"beta")
# Out:
# 0.21689631212908242
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %% [markdown]
# #### inflow profile plot:

# %% [markdown]
# To solve the Stokes (and later the Navier-Stokes) problem, we introduce the bilinear form:
#
# $$
#   a((u,p),(v,q)) := \int_{\Omega} \nu \nabla u : \nabla v - \operatorname{div}(v) p - \operatorname{div}(u) q
# $$

# %% [markdown]
# and directly use it to solve the Stokes problem for suitable initial values:

# %%
# (mu * p + lam * q)

# %%
a = BilinearForm(X)
stokes = (nu*InnerProduct(grad(u),grad(v))-div(u)*q-div(v)*p + mu * p + lam * q)*dx
a += stokes
a.Assemble()

f = LinearForm(X)   
f += InnerProduct(rhs , v) * dx
f.Assemble()

res = f.vec - a.mat*gfu.vec
inv_stokes = a.mat.Inverse(X.FreeDofs())
gfu.vec.data += inv_stokes * res

# %%
sceneu = Draw(velocity,mesh,"u")
scenep = Draw(pressure,mesh,"p")
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…

# %% [markdown]
# ## IMEX time discretization
# For the time integration we consider an semi-implicit Euler method (IMEX) where the convection is treated only explicitly and the remaining part implicitly:
#
# Find $(\mathbf{u}^{n+1},p^{n+1}) \in X = \mathbf{V} \times Q$, s.t. for all $(\mathbf{v},q) \in X = \mathbf{V} \times Q$
#
# \begin{align}
# \underbrace{m(\mathbf{u}^{n+1},\mathbf{v}) + \Delta t ~\cdot~a((\mathbf{u}^{n+1},p^{n+1}),(\mathbf{v},q))}_{ \to M^\ast} ~=~m(\mathbf{u}^{n},\mathbf{v}) - \Delta t ~\cdot~c(\mathbf{u}^{n}; \mathbf{u}^{n},\mathbf{v})
# \end{align}
#
# with
# \begin{align}
# m(\mathbf{u},\mathbf{v}) = \int \mathbf{u} \cdot \mathbf{v}
# \end{align}
#
# and
# \begin{align}
# c(\mathbf{w},\mathbf{u},\mathbf{v}) = \int \mathbf{w} \cdot \nabla \mathbf{u} \cdot \mathbf{v}
# \end{align}
#
# We prefer the incremental form (as it homogenizes the boundary conditions):
# \begin{align}
# m(\delta \mathbf{u}^{n+1},\mathbf{v}) + \Delta t ~\cdot~a((\delta \mathbf{u}^{n+1},\delta p^{n+1}),(\mathbf{v},q)) ~=~ \Delta t (-a((\mathbf{u}^{n},p^n),(\mathbf{v},q)) -c(\mathbf{u}^{n}; \mathbf{u}^{n},\mathbf{v}))
# \end{align}

# %%
# matrix for implicit part of IMEX(1) scheme:
mstar = BilinearForm(X)
mstar += InnerProduct(u,v)*dx + dt*stokes
mstar.Assemble()
inv = mstar.mat.Inverse(X.FreeDofs())

# %% [markdown]
# Next, we want to evaluate the convection term $c(u^n;u^n,v)$ for given $u^n$, i.e. a linear form. We can do this by setting up a `LinearForm`
# ```
# fc = LinearForm(X)
# fc += (Grad(gfu) * gfu) * v * dx
# ```
# Then, for $u^n =$`gfu` a call `fc.Assemble()` yields a vector `fc.vec`representing the linear form.
#
# Alternatively, we can use the semi-linear form structure of the convection form and put it into a `BilinearForm` (which indeed is able to represent non-bilinear forms as we will discuss in more detail in [unit-3.3](../unit-3.3-nonlinear/nonlinear.ipynb)). We will not need the assembly (or the storage of a sparse matrix) though:

# %%
conv = BilinearForm(X, nonassemble = True)
conv += (Grad(u) * u) * v * dx

# %% [markdown]
# Instead of assembling a `LinearForm` in every time step, we use an operator application of a `BilinearForm`, see [unit-2.11](../unit-2.11-matrixfree/matrixfree.ipynb) or the next units for more details.
#
# The `BilinearForm`(which indeed is rather a semi-linear form) can compute the linear form at a given state `u`:
#
#  * either by a call `conv.Apply(gfu.vec,res)` where the result ends up in the vector `res`
#  * alternatively we can use the notation of an operator application `conv.mat * gfu.vec` yielding the same.
#
# Below, we will use the latter.

# %%
tend = 0
gfut = GridFunction(gfu.space,multidim=0)

# %%
# implicit Euler/explicit Euler splitting method:
tend += 1
gfut.AddMultiDimComponent(gfu.vec)
tref = 0; cnt = 0
while t < tend-0.5*dt:
    print ("\rt=", t, end="")
    # Step 1
    ustar.vec.data = 1.5*u_1.vec 
    ustar.vec.data -= 0.5*u_0.vec
    conv.Assemble()
    
    beta_norm.Set(sqrt(InnerProduct(ustar.components[0],ustar.components[0] )) )
    beta_infty = max(beta_norm.vec.FV().NumPy()[:])
    print("beta_infty = ", beta_infty )
    
    jump_ustar = grad(ustar) -  grad(ustar).Other()
    jump_v =  grad(v) -  grad(v).Other()
    
    f = LinearForm(X)   
    f += ( (-1) * InnerProduct(rhs , v) ) * dx
    f += (  nu*InnerProduct(grad(ustar),grad(v)) ) * dx
    f += gammau * h**2 * (  sqrt((ustar*n)**2) + 0.05*beta_infty  ) * InnerProduct (jump_ustar, jump_v  ) * dx(skeleton=True)
    f.Assemble()
    res =  f.vec
    res += conv.mat * ustar.vec
    dustar.vec.data =  invm * fm.vec
    
    # Step 2 
    
    
    tref = tref + dt; cnt += 1
    
    t.Set(tref) 
    f = LinearForm(X)   
    f += InnerProduct(rhs , v) * dx
    #f += InnerProduct(rhs , v) * dx
    
    
    
    res += mmass.mat * gfu.vec
    res -= - dt * conv.mat * gfu.vec
    gfu.vec.data = inv * res    
    
    
    l2_error_vel = sqrt(Integrate( InnerProduct( gfu.components[0] - u_exact ,gfu.components[0] - u_exact  ) ,mesh ))
    l2_error_pressure = sqrt(Integrate( InnerProduct( gfu.components[1] - p_exact ,gfu.components[1] - p_exact  ) ,mesh ))
    print("L2-error=velocity = ",l2_error_vel )
    print("L2-error=pressure = ",l2_error_pressure )
    
    sceneu.Redraw()
    scenep.Redraw()
    if cnt % 50 == 0:
        gfut.AddMultiDimComponent(gfu.vec)
# Out:
# t= ParameterCF, val = 0
# L2-error=velocity =  0.0031068755643873583
# L2-error=pressure =  0.025669680280444314
# t= ParameterCF, val = 0.001
# L2-error=velocity =  0.0031103653745856216
# L2-error=pressure =  0.025706366151775132
# t= ParameterCF, val = 0.002
# L2-error=velocity =  0.0031138227525547165
# L2-error=pressure =  0.025739251060719955
# t= ParameterCF, val = 0.003
# L2-error=velocity =  0.003117234190058516
# L2-error=pressure =  0.025768792456259623
# t= ParameterCF, val = 0.004
# L2-error=velocity =  0.0031205896977768047
# L2-error=pressure =  0.025795384292233298
# t= ParameterCF, val = 0.005
# L2-error=velocity =  0.0031238819910073073
# L2-error=pressure =  0.025819366825609803
# t= ParameterCF, val = 0.006
# L2-error=velocity =  0.003127105877616648
# L2-error=pressure =  0.025841034769515974
# t= ParameterCF, val = 0.007
# L2-error=velocity =  0.0031302577926976744
# L2-error=pressure =  0.02586064409436482
# t= ParameterCF, val = 0.008
# L2-error=velocity =  0.0031333354410941583
# L2-error=pressure =  0.02587841771659592
# t= ParameterCF, val = 0.009
# L2-error=velocity =  0.003136337520259245
# L2-error=pressure =  0.02589455027039107
# t= ParameterCF, val = 0.01
# L2-error=velocity =  0.0031392635036622337
# L2-error=pressure =  0.025909212121766233
# t= ParameterCF, val = 0.011
# L2-error=velocity =  0.00314211347034061
# L2-error=pressure =  0.02592255275516875
# t= ParameterCF, val = 0.012
# L2-error=velocity =  0.0031448879699794937
# L2-error=pressure =  0.02593470363903524
# t= ParameterCF, val = 0.013
# L2-error=velocity =  0.0031475879155972645
# L2-error=pressure =  0.025945780657478216
# t= ParameterCF, val = 0.014
# L2-error=velocity =  0.003150214497862494
# L2-error=pressure =  0.025955886179675588
# t= ParameterCF, val = 0.015
# L2-error=velocity =  0.003152769116486404
# L2-error=pressure =  0.025965110825866618
# t= ParameterCF, val = 0.016
# L2-error=velocity =  0.0031552533251847596
# L2-error=pressure =  0.025973534978523068
# t= ParameterCF, val = 0.017
# L2-error=velocity =  0.003157668787485187
# L2-error=pressure =  0.025981230078903444
# t= ParameterCF, val = 0.018
# L2-error=velocity =  0.0031600172412473487
# L2-error=pressure =  0.025988259742311084
# t= ParameterCF, val = 0.019
# L2-error=velocity =  0.0031623004702126824
# L2-error=pressure =  0.025994680719781737
# t= ParameterCF, val = 0.02
# L2-error=velocity =  0.0031645202812463536
# L2-error=pressure =  0.026000543729347153
# t= ParameterCF, val = 0.021
# L2-error=velocity =  0.003166678486202689
# L2-error=pressure =  0.026005894176208747
# t= ParameterCF, val = 0.022
# L2-error=velocity =  0.00316877688755452
# L2-error=pressure =  0.026010772778057818
# t= ParameterCF, val = 0.023
# L2-error=velocity =  0.0031708172670919825
# L2-error=pressure =  0.026015216109211543
# t= ParameterCF, val = 0.024
# L2-error=velocity =  0.003172801377127563
# L2-error=pressure =  0.026019257075056566
# t= ParameterCF, val = 0.025
# L2-error=velocity =  0.00317473093374806
# L2-error=pressure =  0.026022925326588505
# t= ParameterCF, val = 0.026
# L2-error=velocity =  0.003176607611738414
# L2-error=pressure =  0.026026247623271416
# t= ParameterCF, val = 0.027
# L2-error=velocity =  0.0031784330408698514
# L2-error=pressure =  0.026029248151270903
# t= ParameterCF, val = 0.028
# L2-error=velocity =  0.0031802088032990786
# L2-error=pressure =  0.026031948803035207
# t= ParameterCF, val = 0.029
# L2-error=velocity =  0.003181936431871016
# L2-error=pressure =  0.026034369423368713
# t= ParameterCF, val = 0.03
# L2-error=velocity =  0.0031836174091527778
# L2-error=pressure =  0.02603652802634608
# t= ParameterCF, val = 0.031
# L2-error=velocity =  0.003185253167057548
# L2-error=pressure =  0.026038440986851392
# t= ParameterCF, val = 0.032
# L2-error=velocity =  0.003186845086941067
# L2-error=pressure =  0.026040123209985243
# t= ParameterCF, val = 0.033
# L2-error=velocity =  0.0031883945000738354
# L2-error=pressure =  0.02604158828110524
# t= ParameterCF, val = 0.034
# L2-error=velocity =  0.0031899026884093184
# L2-error=pressure =  0.026042848598937404
# t= ParameterCF, val = 0.035
# L2-error=velocity =  0.003191370885581792
# L2-error=pressure =  0.026043915493817443
# t= ParameterCF, val = 0.036
# L2-error=velocity =  0.003192800278079557
# L2-error=pressure =  0.0260447993328926
# t= ParameterCF, val = 0.037
# L2-error=velocity =  0.0031941920065485982
# L2-error=pressure =  0.026045509613835637
# t= ParameterCF, val = 0.038
# L2-error=velocity =  0.00319554716718972
# L2-error=pressure =  0.026046055048452383
# t= ParameterCF, val = 0.039
# L2-error=velocity =  0.0031968668132191683
# L2-error=pressure =  0.02604644363735852
# t= ParameterCF, val = 0.04
# L2-error=velocity =  0.003198151956367873
# L2-error=pressure =  0.02604668273678121
# t= ParameterCF, val = 0.041
# L2-error=velocity =  0.003199403568399495
# L2-error=pressure =  0.026046779118374445
# t= ParameterCF, val = 0.042
# L2-error=velocity =  0.003200622582630974
# L2-error=pressure =  0.02604673902286066
# t= ParameterCF, val = 0.043
# L2-error=velocity =  0.0032018098954427724
# L2-error=pressure =  0.02604656820819419
# t= ParameterCF, val = 0.044
# L2-error=velocity =  0.0032029663677684765
# L2-error=pressure =  0.026046271992840105
# t= ParameterCF, val = 0.045
# L2-error=velocity =  0.0032040928265556165
# L2-error=pressure =  0.026045855294737803
# t= ParameterCF, val = 0.046
# L2-error=velocity =  0.0032051900661918377
# L2-error=pressure =  0.026045322666386747
# t= ParameterCF, val = 0.047
# L2-error=velocity =  0.0032062588498913956
# L2-error=pressure =  0.026044678326523896
# t= ParameterCF, val = 0.048
# L2-error=velocity =  0.0032072999110387647
# L2-error=pressure =  0.026043926188692224
# t= ParameterCF, val = 0.049
# L2-error=velocity =  0.00320831395448701
# L2-error=pressure =  0.026043069887097627
# t= ParameterCF, val = 0.05
# L2-error=velocity =  0.0032093016578091807
# L2-error=pressure =  0.026042112799991985
# t= ParameterCF, val = 0.051
# L2-error=velocity =  0.003210263672502407
# L2-error=pressure =  0.026041058070865517
# t= ParameterCF, val = 0.052
# L2-error=velocity =  0.003211200625143811
# L2-error=pressure =  0.02603990862766373
# t= ParameterCF, val = 0.053
# L2-error=velocity =  0.0032121131184989493
# L2-error=pressure =  0.026038667200230455
# t= ParameterCF, val = 0.054
# L2-error=velocity =  0.0032130017325830195
# L2-error=pressure =  0.02603733633616975
# t= ParameterCF, val = 0.055
# L2-error=velocity =  0.003213867025675953
# L2-error=pressure =  0.026035918415265723
# t= ParameterCF, val = 0.056
# L2-error=velocity =  0.003214709535292292
# L2-error=pressure =  0.02603441566261344
# t= ParameterCF, val = 0.057
# L2-error=velocity =  0.003215529779107019
# L2-error=pressure =  0.02603283016060411
# t= ParameterCF, val = 0.058
# L2-error=velocity =  0.003216328255838909
# L2-error=pressure =  0.026031163859830637
# t= ParameterCF, val = 0.059
# L2-error=velocity =  0.0032171054460927695
# L2-error=pressure =  0.026029418589078986
# t= ParameterCF, val = 0.06
# L2-error=velocity =  0.0032178618131619937
# L2-error=pressure =  0.02602759606443643
# t= ParameterCF, val = 0.061
# L2-error=velocity =  0.003218597803793097
# L2-error=pressure =  0.026025697897639123
# t= ParameterCF, val = 0.062
# L2-error=velocity =  0.003219313848913705
# L2-error=pressure =  0.026023725603712213
# t= ParameterCF, val = 0.063
# L2-error=velocity =  0.0032200103643255855
# L2-error=pressure =  0.026021680607975425
# t= ParameterCF, val = 0.064
# L2-error=velocity =  0.003220687751364299
# L2-error=pressure =  0.02601956425246308
# t= ParameterCF, val = 0.065
# L2-error=velocity =  0.0032213463975267792
# L2-error=pressure =  0.026017377801828348
# t= ParameterCF, val = 0.066
# L2-error=velocity =  0.0032219866770687635
# L2-error=pressure =  0.02601512244876109
# t= ParameterCF, val = 0.067
# L2-error=velocity =  0.0032226089515728813
# L2-error=pressure =  0.026012799318981823
# t= ParameterCF, val = 0.068
# L2-error=velocity =  0.00322321357048945
# L2-error=pressure =  0.02601040947582448
# t= ParameterCF, val = 0.069
# L2-error=velocity =  0.003223800871650817
# L2-error=pressure =  0.026007953924470972
# t= ParameterCF, val = 0.07
# L2-error=velocity =  0.0032243711817607655
# L2-error=pressure =  0.026005433615851687
# t= ParameterCF, val = 0.071
# L2-error=velocity =  0.0032249248168603585
# L2-error=pressure =  0.026002849450240728
# t= ParameterCF, val = 0.072
# L2-error=velocity =  0.0032254620827709903
# L2-error=pressure =  0.026000202280590204
# t= ParameterCF, val = 0.073
# L2-error=velocity =  0.003225983275516354
# L2-error=pressure =  0.025997492915588852
# t= ParameterCF, val = 0.074
# L2-error=velocity =  0.003226488681723887
# L2-error=pressure =  0.02599472212251759
# t= ParameterCF, val = 0.075
# L2-error=velocity =  0.0032269785790071154
# L2-error=pressure =  0.025991890629872533
# t= ParameterCF, val = 0.076
# L2-error=velocity =  0.003227453236329608
# L2-error=pressure =  0.02598899912981027
# t= ParameterCF, val = 0.077
# L2-error=velocity =  0.00322791291435177
# L2-error=pressure =  0.025986048280396055
# t= ParameterCF, val = 0.078
# L2-error=velocity =  0.0032283578657610755
# L2-error=pressure =  0.025983038707718144
# t= ParameterCF, val = 0.079
# L2-error=velocity =  0.003228788335586735
# L2-error=pressure =  0.02597997100782171
# t= ParameterCF, val = 0.08
# L2-error=velocity =  0.0032292045614997016
# L2-error=pressure =  0.025976845748523682
# t= ParameterCF, val = 0.081
# L2-error=velocity =  0.003229606774098642
# L2-error=pressure =  0.025973663471094824
# t= ParameterCF, val = 0.082
# L2-error=velocity =  0.0032299951971824837
# L2-error=pressure =  0.025970424691829627
# t= ParameterCF, val = 0.083
# L2-error=velocity =  0.0032303700480105346
# L2-error=pressure =  0.025967129903495156
# t= ParameterCF, val = 0.084
# L2-error=velocity =  0.0032307315375506686
# L2-error=pressure =  0.02596377957670282
# t= ParameterCF, val = 0.085
# L2-error=velocity =  0.003231079870716014
# L2-error=pressure =  0.025960374161162484
# t= ParameterCF, val = 0.086
# L2-error=velocity =  0.0032314152465910914
# L2-error=pressure =  0.02595691408687727
# t= ParameterCF, val = 0.087
# L2-error=velocity =  0.0032317378586476874
# L2-error=pressure =  0.025953399765239648
# t= ParameterCF, val = 0.088
# L2-error=velocity =  0.0032320478949509532
# L2-error=pressure =  0.025949831590063702
# t= ParameterCF, val = 0.089
# L2-error=velocity =  0.0032323455383564655
# L2-error=pressure =  0.02594620993855901
# t= ParameterCF, val = 0.09
# L2-error=velocity =  0.0032326309666985756
# L2-error=pressure =  0.025942535172218655
# t= ParameterCF, val = 0.091
# L2-error=velocity =  0.003232904352970346
# L2-error=pressure =  0.025938807637679643
# t= ParameterCF, val = 0.092
# L2-error=velocity =  0.0032331658654957476
# L2-error=pressure =  0.025935027667505405
# t= ParameterCF, val = 0.093
# L2-error=velocity =  0.003233415668094378
# L2-error=pressure =  0.025931195580929836
# t= ParameterCF, val = 0.094
# L2-error=velocity =  0.0032336539202390854
# L2-error=pressure =  0.02592731168455945
# t= ParameterCF, val = 0.095
# L2-error=velocity =  0.0032338807772068056
# L2-error=pressure =  0.025923376273017194
# t= ParameterCF, val = 0.096
# L2-error=velocity =  0.0032340963902230376
# L2-error=pressure =  0.025919389629565578
# t= ParameterCF, val = 0.097
# L2-error=velocity =  0.0032343009066002526
# L2-error=pressure =  0.025915352026682426
# t= ParameterCF, val = 0.098
# L2-error=velocity =  0.0032344944698704803
# L2-error=pressure =  0.02591126372659832
# t= ParameterCF, val = 0.099
# L2-error=velocity =  0.003234677219912365
# L2-error=pressure =  0.0259071249818109
# t= ParameterCF, val = 0.1
# L2-error=velocity =  0.0032348492930730243
# L2-error=pressure =  0.025902936035567644
# t= ParameterCF, val = 0.101
# L2-error=velocity =  0.0032350108222849
# L2-error=pressure =  0.025898697122316894
# t= ParameterCF, val = 0.102
# L2-error=velocity =  0.0032351619371778027
# L2-error=pressure =  0.02589440846813367
# t= ParameterCF, val = 0.103
# L2-error=velocity =  0.0032353027641865736
# L2-error=pressure =  0.02589007029112329
# t= ParameterCF, val = 0.104
# L2-error=velocity =  0.003235433426654223
# L2-error=pressure =  0.025885682801805924
# t= ParameterCF, val = 0.105
# L2-error=velocity =  0.003235554044931166
# L2-error=pressure =  0.02588124620346428
# t= ParameterCF, val = 0.106
# L2-error=velocity =  0.0032356647364704645
# L2-error=pressure =  0.02587676069249664
# t= ParameterCF, val = 0.107
# L2-error=velocity =  0.003235765615919229
# L2-error=pressure =  0.025872226458726128
# t= ParameterCF, val = 0.108
# L2-error=velocity =  0.0032358567952066202
# L2-error=pressure =  0.025867643685712073
# t= ParameterCF, val = 0.109
# L2-error=velocity =  0.003235938383628379
# L2-error=pressure =  0.02586301255102976
# t= ParameterCF, val = 0.11
# L2-error=velocity =  0.0032360104879281416
# L2-error=pressure =  0.025858333226546622
# t= ParameterCF, val = 0.111
# L2-error=velocity =  0.0032360732123755415
# L2-error=pressure =  0.025853605878677414
# t= ParameterCF, val = 0.112
# L2-error=velocity =  0.0032361266588415193
# L2-error=pressure =  0.025848830668631532
# t= ParameterCF, val = 0.113
# L2-error=velocity =  0.0032361709268707048
# L2-error=pressure =  0.02584400775263725
# t= ParameterCF, val = 0.114
# L2-error=velocity =  0.0032362061137511185
# L2-error=pressure =  0.025839137282167673
# t= ParameterCF, val = 0.115
# L2-error=velocity =  0.0032362323145813388
# L2-error=pressure =  0.02583421940414763
# t= ParameterCF, val = 0.116
# L2-error=velocity =  0.0032362496223350837
# L2-error=pressure =  0.025829254261146982
# t= ParameterCF, val = 0.117
# L2-error=velocity =  0.003236258127923577
# L2-error=pressure =  0.025824241991575896
# t= ParameterCF, val = 0.118
# L2-error=velocity =  0.0032362579202555595
# L2-error=pressure =  0.02581918272985449
# t= ParameterCF, val = 0.119
# L2-error=velocity =  0.0032362490862951755
# L2-error=pressure =  0.02581407660659172
# t= ParameterCF, val = 0.12
# L2-error=velocity =  0.003236231711117754
# L2-error=pressure =  0.025808923748738166
# t= ParameterCF, val = 0.121
# L2-error=velocity =  0.0032362058779636855
# L2-error=pressure =  0.025803724279749286
# t= ParameterCF, val = 0.122
# L2-error=velocity =  0.003236171668290285
# L2-error=pressure =  0.025798478319721797
# t= ParameterCF, val = 0.123
# L2-error=velocity =  0.0032361291618219746
# L2-error=pressure =  0.02579318598553984
# t= ParameterCF, val = 0.124
# L2-error=velocity =  0.0032360784365986005
# L2-error=pressure =  0.025787847391006764
# t= ParameterCF, val = 0.125
# L2-error=velocity =  0.003236019569022164
# L2-error=pressure =  0.02578246264697042
# t= ParameterCF, val = 0.126
# L2-error=velocity =  0.0032359526339018753
# L2-error=pressure =  0.025777031861444942
# t= ParameterCF, val = 0.127
# L2-error=velocity =  0.0032358777044977573
# L2-error=pressure =  0.025771555139725413
# t= ParameterCF, val = 0.128
# L2-error=velocity =  0.0032357948525627137
# L2-error=pressure =  0.025766032584497535
# t= ParameterCF, val = 0.129
# L2-error=velocity =  0.0032357041483831884
# L2-error=pressure =  0.025760464295948592
# t= ParameterCF, val = 0.13
# L2-error=velocity =  0.0032356056608184914
# L2-error=pressure =  0.02575485037185664
# t= ParameterCF, val = 0.131
# L2-error=velocity =  0.003235499457338795
# L2-error=pressure =  0.025749190907696905
# t= ParameterCF, val = 0.132
# L2-error=velocity =  0.003235385604061873
# L2-error=pressure =  0.025743485996728405
# t= ParameterCF, val = 0.133
# L2-error=velocity =  0.0032352641657886856
# L2-error=pressure =  0.025737735730084546
# t= ParameterCF, val = 0.134
# L2-error=velocity =  0.0032351352060377486
# L2-error=pressure =  0.025731940196851398
# t= ParameterCF, val = 0.135
# L2-error=velocity =  0.003234998787078408
# L2-error=pressure =  0.025726099484159007
# t= ParameterCF, val = 0.136
# L2-error=velocity =  0.003234854969963091
# L2-error=pressure =  0.025720213677244152
# t= ParameterCF, val = 0.137
# L2-error=velocity =  0.003234703814558433
# L2-error=pressure =  0.025714282859537595
# t= ParameterCF, val = 0.138
# L2-error=velocity =  0.0032345453795754897
# L2-error=pressure =  0.02570830711272652
# t= ParameterCF, val = 0.139
# L2-error=velocity =  0.0032343797225990053
# L2-error=pressure =  0.0257022865168237
# t= ParameterCF, val = 0.14
# L2-error=velocity =  0.0032342069001156863
# L2-error=pressure =  0.025696221150234094
# t= ParameterCF, val = 0.141
# L2-error=velocity =  0.003234026967541675
# L2-error=pressure =  0.025690111089816087
# t= ParameterCF, val = 0.142
# L2-error=velocity =  0.003233839979249177
# L2-error=pressure =  0.025683956410940553
# t= ParameterCF, val = 0.143
# L2-error=velocity =  0.003233645988592196
# L2-error=pressure =  0.02567775718754882
# t= ParameterCF, val = 0.144
# L2-error=velocity =  0.0032334450479314884
# L2-error=pressure =  0.02567151349221156
# t= ParameterCF, val = 0.145
# L2-error=velocity =  0.0032332372086588536
# L2-error=pressure =  0.025665225396172445
# t= ParameterCF, val = 0.146
# L2-error=velocity =  0.0032330225212206204
# L2-error=pressure =  0.025658892969405808
# t= ParameterCF, val = 0.147
# L2-error=velocity =  0.0032328010351404166
# L2-error=pressure =  0.025652516280665498
# t= ParameterCF, val = 0.148
# L2-error=velocity =  0.0032325727990412867
# L2-error=pressure =  0.025646095397529396
# t= ParameterCF, val = 0.149
# L2-error=velocity =  0.003232337860667111
# L2-error=pressure =  0.025639630386441743
# t= ParameterCF, val = 0.15
# L2-error=velocity =  0.003232096266903508
# L2-error=pressure =  0.025633121312765805
# t= ParameterCF, val = 0.151
# L2-error=velocity =  0.0032318480637979637
# L2-error=pressure =  0.025626568240814267
# t= ParameterCF, val = 0.152
# L2-error=velocity =  0.0032315932965795297
# L2-error=pressure =  0.02561997123389558
# t= ParameterCF, val = 0.153
# L2-error=velocity =  0.0032313320096778106
# L2-error=pressure =  0.025613330354353085
# t= ParameterCF, val = 0.154
# L2-error=velocity =  0.0032310642467414928
# L2-error=pressure =  0.025606645663597858
# t= ParameterCF, val = 0.155
# L2-error=velocity =  0.003230790050656329
# L2-error=pressure =  0.025599917222148792
# t= ParameterCF, val = 0.156
# L2-error=velocity =  0.0032305094635625624
# L2-error=pressure =  0.025593145089663625
# t= ParameterCF, val = 0.157
# L2-error=velocity =  0.0032302225268719706
# L2-error=pressure =  0.02558632932497239
# t= ParameterCF, val = 0.158
# L2-error=velocity =  0.003229929281284228
# L2-error=pressure =  0.02557946998611428
# t= ParameterCF, val = 0.159
# L2-error=velocity =  0.003229629766803069
# L2-error=pressure =  0.02557256713036007
# t= ParameterCF, val = 0.16
# L2-error=velocity =  0.003229324022751794
# L2-error=pressure =  0.025565620814247614
# t= ParameterCF, val = 0.161
# L2-error=velocity =  0.0032290120877883845
# L2-error=pressure =  0.025558631093609275
# t= ParameterCF, val = 0.162
# L2-error=velocity =  0.003228693999920364
# L2-error=pressure =  0.025551598023598292
# t= ParameterCF, val = 0.163
# L2-error=velocity =  0.0032283697965189762
# L2-error=pressure =  0.025544521658715
# t= ParameterCF, val = 0.164
# L2-error=velocity =  0.0032280395143332186
# L2-error=pressure =  0.02553740205283647
# t= ParameterCF, val = 0.165
# L2-error=velocity =  0.0032277031895033797
# L2-error=pressure =  0.025530239259232597
# t= ParameterCF, val = 0.166
# L2-error=velocity =  0.003227360857574181
# L2-error=pressure =  0.025523033330601692
# t= ParameterCF, val = 0.167
# L2-error=velocity =  0.0032270125535077254
# L2-error=pressure =  0.025515784319082524
# t= ParameterCF, val = 0.168
# L2-error=velocity =  0.0032266583116958725
# L2-error=pressure =  0.025508492276282425
# t= ParameterCF, val = 0.169
# L2-error=velocity =  0.0032262981659725034
# L2-error=pressure =  0.025501157253297123
# t= ParameterCF, val = 0.17
# L2-error=velocity =  0.003225932149625309
# L2-error=pressure =  0.025493779300732766
# t= ParameterCF, val = 0.171
# L2-error=velocity =  0.0032255602954073554
# L2-error=pressure =  0.02548635846872249
# t= ParameterCF, val = 0.172
# L2-error=velocity =  0.0032251826355483215
# L2-error=pressure =  0.02547889480694955
# t= ParameterCF, val = 0.173
# L2-error=velocity =  0.0032247992017653995
# L2-error=pressure =  0.025471388364663318
# t= ParameterCF, val = 0.174
# L2-error=velocity =  0.0032244100252740034
# L2-error=pressure =  0.025463839190698882
# t= ParameterCF, val = 0.175
# L2-error=velocity =  0.0032240151367981633
# L2-error=pressure =  0.02545624733349438
# t= ParameterCF, val = 0.176
# L2-error=velocity =  0.003223614566580552
# L2-error=pressure =  0.025448612841104397
# t= ParameterCF, val = 0.177
# L2-error=velocity =  0.003223208344392466
# L2-error=pressure =  0.025440935761222708
# t= ParameterCF, val = 0.178
# L2-error=velocity =  0.003222796499543384
# L2-error=pressure =  0.025433216141190127
# t= ParameterCF, val = 0.179
# L2-error=velocity =  0.003222379060890343
# L2-error=pressure =  0.025425454028017214
# t= ParameterCF, val = 0.18
# L2-error=velocity =  0.0032219560568471145
# L2-error=pressure =  0.025417649468392367
# t= ParameterCF, val = 0.181
# L2-error=velocity =  0.0032215275153930096
# L2-error=pressure =  0.02540980250870101
# t= ParameterCF, val = 0.182
# L2-error=velocity =  0.0032210934640817057
# L2-error=pressure =  0.025401913195037852
# t= ParameterCF, val = 0.183
# L2-error=velocity =  0.0032206539300496362
# L2-error=pressure =  0.02539398157321722
# t= ParameterCF, val = 0.184
# L2-error=velocity =  0.003220208940024282
# L2-error=pressure =  0.025386007688790905
# t= ParameterCF, val = 0.185
# L2-error=velocity =  0.003219758520332263
# L2-error=pressure =  0.025377991587055886
# t= ParameterCF, val = 0.186
# L2-error=velocity =  0.003219302696907164
# L2-error=pressure =  0.025369933313067604
# t= ParameterCF, val = 0.187
# L2-error=velocity =  0.0032188414952972625
# L2-error=pressure =  0.02536183291165665
# t= ParameterCF, val = 0.188
# L2-error=velocity =  0.0032183749406729726
# L2-error=pressure =  0.025353690427428504
# t= ParameterCF, val = 0.189
# L2-error=velocity =  0.0032179030578342108
# L2-error=pressure =  0.02534550590478994
# t= ParameterCF, val = 0.19
# L2-error=velocity =  0.0032174258712175568
# L2-error=pressure =  0.0253372793879452
# t= ParameterCF, val = 0.191
# L2-error=velocity =  0.003216943404903151
# L2-error=pressure =  0.025329010920913234
# t= ParameterCF, val = 0.192
# L2-error=velocity =  0.003216455682621568
# L2-error=pressure =  0.02532070054753838
# t= ParameterCF, val = 0.193
# L2-error=velocity =  0.0032159627277604627
# L2-error=pressure =  0.025312348311496598
# t= ParameterCF, val = 0.194
# L2-error=velocity =  0.0032154645633710845
# L2-error=pressure =  0.025303954256305626
# t= ParameterCF, val = 0.195
# L2-error=velocity =  0.0032149612121745285
# L2-error=pressure =  0.025295518425335665
# t= ParameterCF, val = 0.196
# L2-error=velocity =  0.0032144526965680997
# L2-error=pressure =  0.025287040861815772
# t= ParameterCF, val = 0.197
# L2-error=velocity =  0.003213939038631205
# L2-error=pressure =  0.025278521608843148
# t= ParameterCF, val = 0.198
# L2-error=velocity =  0.0032134202601313664
# L2-error=pressure =  0.02526996070939358
# t= ParameterCF, val = 0.199
# L2-error=velocity =  0.0032128963825300127
# L2-error=pressure =  0.02526135820632348
# t= ParameterCF, val = 0.2
# L2-error=velocity =  0.0032123674269881166
# L2-error=pressure =  0.025252714142384624
# t= ParameterCF, val = 0.201
# L2-error=velocity =  0.0032118334143716974
# L2-error=pressure =  0.025244028560226308
# t= ParameterCF, val = 0.202
# L2-error=velocity =  0.0032112943652572463
# L2-error=pressure =  0.025235301502402826
# t= ParameterCF, val = 0.203
# L2-error=velocity =  0.0032107502999370197
# L2-error=pressure =  0.025226533011387598
# t= ParameterCF, val = 0.204
# L2-error=velocity =  0.00321020123842419
# L2-error=pressure =  0.025217723129565352
# t= ParameterCF, val = 0.205
# L2-error=velocity =  0.0032096472004579076
# L2-error=pressure =  0.025208871899254675
# t= ParameterCF, val = 0.206
# L2-error=velocity =  0.003209088205508282
# L2-error=pressure =  0.025199979362703684
# t= ParameterCF, val = 0.207
# L2-error=velocity =  0.003208524272781121
# L2-error=pressure =  0.02519104556210298
# t= ParameterCF, val = 0.208
# L2-error=velocity =  0.0032079554212227288
# L2-error=pressure =  0.025182070539580034
# t= ParameterCF, val = 0.209
# L2-error=velocity =  0.0032073816695245517
# L2-error=pressure =  0.0251730543372232
# t= ParameterCF, val = 0.21
# L2-error=velocity =  0.0032068030361276957
# L2-error=pressure =  0.025163996997070663
# t= ParameterCF, val = 0.211
# L2-error=velocity =  0.0032062195392272936
# L2-error=pressure =  0.025154898561123032
# t= ParameterCF, val = 0.212
# L2-error=velocity =  0.003205631196776895
# L2-error=pressure =  0.025145759071350825
# t= ParameterCF, val = 0.213
# L2-error=velocity =  0.0032050380264927333
# L2-error=pressure =  0.025136578569691308
# t= ParameterCF, val = 0.214
# L2-error=velocity =  0.0032044400458578117
# L2-error=pressure =  0.025127357098063647
# t= ParameterCF, val = 0.215
# L2-error=velocity =  0.0032038372721260623
# L2-error=pressure =  0.02511809469836647
# t= ParameterCF, val = 0.216
# L2-error=velocity =  0.003203229722326257
# L2-error=pressure =  0.02510879141248346
# t= ParameterCF, val = 0.217
# L2-error=velocity =  0.0032026174132659384
# L2-error=pressure =  0.02509944728229047
# t= ParameterCF, val = 0.218
# L2-error=velocity =  0.0032020003615352262
# L2-error=pressure =  0.025090062349659353
# t= ParameterCF, val = 0.219
# L2-error=velocity =  0.0032013785835105866
# L2-error=pressure =  0.025080636656458224
# t= ParameterCF, val = 0.22
# L2-error=velocity =  0.0032007520953584567
# L2-error=pressure =  0.025071170244561125
# t= ParameterCF, val = 0.221
# L2-error=velocity =  0.0032001209130388566
# L2-error=pressure =  0.025061663155848613
# t= ParameterCF, val = 0.222
# L2-error=velocity =  0.003199485052308915
# L2-error=pressure =  0.02505211543221041
# t= ParameterCF, val = 0.223
# L2-error=velocity =  0.003198844528726306
# L2-error=pressure =  0.025042527115555407
# t= ParameterCF, val = 0.224
# L2-error=velocity =  0.003198199357652633
# L2-error=pressure =  0.025032898247805004
# t= ParameterCF, val = 0.225
# L2-error=velocity =  0.0031975495542567317
# L2-error=pressure =  0.025023228870908187
# t= ParameterCF, val = 0.226
# L2-error=velocity =  0.0031968951335178747
# L2-error=pressure =  0.025013519026835986
# t= ParameterCF, val = 0.227
# L2-error=velocity =  0.0031962361102290575
# L2-error=pressure =  0.02500376875758829
# t= ParameterCF, val = 0.228
# L2-error=velocity =  0.003195572498999981
# L2-error=pressure =  0.02499397810519581
# t= ParameterCF, val = 0.229
# L2-error=velocity =  0.0031949043142602204
# L2-error=pressure =  0.024984147111728857
# t= ParameterCF, val = 0.23
# L2-error=velocity =  0.0031942315702621553
# L2-error=pressure =  0.024974275819287545
# t= ParameterCF, val = 0.231
# L2-error=velocity =  0.0031935542810838952
# L2-error=pressure =  0.02496436427002169
# t= ParameterCF, val = 0.232
# L2-error=velocity =  0.0031928724606322526
# L2-error=pressure =  0.024954412506117074
# t= ParameterCF, val = 0.233
# L2-error=velocity =  0.0031921861226454594
# L2-error=pressure =  0.024944420569809472
# t= ParameterCF, val = 0.234
# L2-error=velocity =  0.003191495280696001
# L2-error=pressure =  0.024934388503384156
# t= ParameterCF, val = 0.235
# L2-error=velocity =  0.003190799948193316
# L2-error=pressure =  0.024924316349172543
# t= ParameterCF, val = 0.236
# L2-error=velocity =  0.0031901001383864485
# L2-error=pressure =  0.024914204149570022
# t= ParameterCF, val = 0.237
# L2-error=velocity =  0.0031893958643667
# L2-error=pressure =  0.024904051947017253
# t= ParameterCF, val = 0.238
# L2-error=velocity =  0.0031886871390701373
# L2-error=pressure =  0.024893859784021057
# t= ParameterCF, val = 0.239
# L2-error=velocity =  0.003187973975280172
# L2-error=pressure =  0.02488362770314588
# t= ParameterCF, val = 0.24
# L2-error=velocity =  0.00318725638563003
# L2-error=pressure =  0.02487335574701895
# t= ParameterCF, val = 0.241
# L2-error=velocity =  0.0031865343826051012
# L2-error=pressure =  0.02486304395833498
# t= ParameterCF, val = 0.242
# L2-error=velocity =  0.0031858079785454184
# L2-error=pressure =  0.024852692379854963
# t= ParameterCF, val = 0.243
# L2-error=velocity =  0.0031850771856478943
# L2-error=pressure =  0.02484230105440913
# t= ParameterCF, val = 0.244
# L2-error=velocity =  0.0031843420159687226
# L2-error=pressure =  0.02483187002489757
# t= ParameterCF, val = 0.245
# L2-error=velocity =  0.0031836024814255225
# L2-error=pressure =  0.02482139933429703
# t= ParameterCF, val = 0.246
# L2-error=velocity =  0.0031828585937996277
# L2-error=pressure =  0.024810889025655116
# t= ParameterCF, val = 0.247
# L2-error=velocity =  0.0031821103647382254
# L2-error=pressure =  0.02480033914209762
# t= ParameterCF, val = 0.248
# L2-error=velocity =  0.0031813578057564677
# L2-error=pressure =  0.024789749726830786
# t= ParameterCF, val = 0.249
# L2-error=velocity =  0.0031806009282396457
# L2-error=pressure =  0.02477912082313637
# t= ParameterCF, val = 0.25
# L2-error=velocity =  0.0031798397434451096
# L2-error=pressure =  0.024768452474385538
# t= ParameterCF, val = 0.251
# L2-error=velocity =  0.0031790742625044228
# L2-error=pressure =  0.024757744724021764
# t= ParameterCF, val = 0.252
# L2-error=velocity =  0.003178304496425265
# L2-error=pressure =  0.02474699761558246
# t= ParameterCF, val = 0.253
# L2-error=velocity =  0.0031775304560933875
# L2-error=pressure =  0.024736211192687353
# t= ParameterCF, val = 0.254
# L2-error=velocity =  0.0031767521522745455
# L2-error=pressure =  0.02472538549904378
# t= ParameterCF, val = 0.255
# L2-error=velocity =  0.0031759695956163664
# L2-error=pressure =  0.024714520578449445
# t= ParameterCF, val = 0.256
# L2-error=velocity =  0.003175182796650248
# L2-error=pressure =  0.024703616474789136
# t= ParameterCF, val = 0.257
# L2-error=velocity =  0.003174391765793075
# L2-error=pressure =  0.02469267323204336
# t= ParameterCF, val = 0.258
# L2-error=velocity =  0.003173596513349064
# L2-error=pressure =  0.024681690894281776
# t= ParameterCF, val = 0.259
# L2-error=velocity =  0.0031727970495115223
# L2-error=pressure =  0.02467066950567084
# t= ParameterCF, val = 0.26
# L2-error=velocity =  0.0031719933843645442
# L2-error=pressure =  0.02465960911047035
# t= ParameterCF, val = 0.261
# L2-error=velocity =  0.003171185527884724
# L2-error=pressure =  0.024648509753035956
# t= ParameterCF, val = 0.262
# L2-error=velocity =  0.0031703734899427927
# L2-error=pressure =  0.024637371477822873
# t= ParameterCF, val = 0.263
# L2-error=velocity =  0.0031695572803052937
# L2-error=pressure =  0.024626194329382248
# t= ParameterCF, val = 0.264
# L2-error=velocity =  0.0031687369086361486
# L2-error=pressure =  0.024614978352366455
# t= ParameterCF, val = 0.265
# L2-error=velocity =  0.0031679123844982663
# L2-error=pressure =  0.0246037235915256
# t= ParameterCF, val = 0.266
# L2-error=velocity =  0.0031670837173550874
# L2-error=pressure =  0.024592430091715748
# t= ParameterCF, val = 0.267
# L2-error=velocity =  0.0031662509165721305
# L2-error=pressure =  0.024581097897889728
# t= ParameterCF, val = 0.268
# L2-error=velocity =  0.0031654139914184367
# L2-error=pressure =  0.024569727055109198
# t= ParameterCF, val = 0.269
# L2-error=velocity =  0.00316457295106813
# L2-error=pressure =  0.02455831760853307
# t= ParameterCF, val = 0.27
# L2-error=velocity =  0.0031637278046018126
# L2-error=pressure =  0.024546869603432084
# t= ParameterCF, val = 0.271
# L2-error=velocity =  0.003162878561008025
# L2-error=pressure =  0.024535383085176183
# t= ParameterCF, val = 0.272
# L2-error=velocity =  0.0031620252291846033
# L2-error=pressure =  0.024523858099248518
# t= ParameterCF, val = 0.273
# L2-error=velocity =  0.0031611678179401257
# L2-error=pressure =  0.0245122946912316
# t= ParameterCF, val = 0.274
# L2-error=velocity =  0.0031603063359952306
# L2-error=pressure =  0.024500692906822955
# t= ParameterCF, val = 0.275
# L2-error=velocity =  0.0031594407919839766
# L2-error=pressure =  0.024489052791825353
# t= ParameterCF, val = 0.276
# L2-error=velocity =  0.00315857119445514
# L2-error=pressure =  0.024477374392147946
# t= ParameterCF, val = 0.277
# L2-error=velocity =  0.00315769755187351
# L2-error=pressure =  0.024465657753815002
# t= ParameterCF, val = 0.278
# L2-error=velocity =  0.003156819872621206
# L2-error=pressure =  0.02445390292295876
# t= ParameterCF, val = 0.279
# L2-error=velocity =  0.0031559381649988202
# L2-error=pressure =  0.024442109945823322
# t= ParameterCF, val = 0.28
# L2-error=velocity =  0.0031550524372268417
# L2-error=pressure =  0.024430278868763488
# t= ParameterCF, val = 0.281
# L2-error=velocity =  0.0031541626974466485
# L2-error=pressure =  0.024418409738245096
# t= ParameterCF, val = 0.282
# L2-error=velocity =  0.0031532689537218522
# L2-error=pressure =  0.02440650260085163
# t= ParameterCF, val = 0.283
# L2-error=velocity =  0.0031523712140394426
# L2-error=pressure =  0.024394557503273434
# t= ParameterCF, val = 0.284
# L2-error=velocity =  0.0031514694863108905
# L2-error=pressure =  0.024382574492320907
# t= ParameterCF, val = 0.285
# L2-error=velocity =  0.0031505637783733583
# L2-error=pressure =  0.024370553614912336
# t= ParameterCF, val = 0.286
# L2-error=velocity =  0.0031496540979907843
# L2-error=pressure =  0.02435849491808598
# t= ParameterCF, val = 0.287
# L2-error=velocity =  0.0031487404528549984
# L2-error=pressure =  0.02434639844899059
# t= ParameterCF, val = 0.288
# L2-error=velocity =  0.0031478228505867883
# L2-error=pressure =  0.024334264254896817
# t= ParameterCF, val = 0.289
# L2-error=velocity =  0.003146901298736965
# L2-error=pressure =  0.024322092383185
# t= ParameterCF, val = 0.29
# L2-error=velocity =  0.003145975804787478
# L2-error=pressure =  0.024309882881355327
# t= ParameterCF, val = 0.291
# L2-error=velocity =  0.0031450463761523496
# L2-error=pressure =  0.024297635797024087
# t= ParameterCF, val = 0.292
# L2-error=velocity =  0.0031441130201787858
# L2-error=pressure =  0.024285351177923045
# t= ParameterCF, val = 0.293
# L2-error=velocity =  0.0031431757441481244
# L2-error=pressure =  0.024273029071904956
# t= ParameterCF, val = 0.294
# L2-error=velocity =  0.0031422345552768304
# L2-error=pressure =  0.024260669526933853
# t= ParameterCF, val = 0.295
# L2-error=velocity =  0.0031412894607175256
# L2-error=pressure =  0.024248272591100187
# t= ParameterCF, val = 0.296
# L2-error=velocity =  0.0031403404675598716
# L2-error=pressure =  0.024235838312607796
# t= ParameterCF, val = 0.297
# L2-error=velocity =  0.003139387582831557
# L2-error=pressure =  0.024223366739779015
# t= ParameterCF, val = 0.298
# L2-error=velocity =  0.0031384308134991988
# L2-error=pressure =  0.024210857921056643
# t= ParameterCF, val = 0.299
# L2-error=velocity =  0.003137470166469296
# L2-error=pressure =  0.02419831190500145
# t= ParameterCF, val = 0.3
# L2-error=velocity =  0.003136505648589086
# L2-error=pressure =  0.024185728740295176
# t= ParameterCF, val = 0.301
# L2-error=velocity =  0.0031355372666474835
# L2-error=pressure =  0.024173108475736747
# t= ParameterCF, val = 0.302
# L2-error=velocity =  0.003134565027375934
# L2-error=pressure =  0.024160451160249393
# t= ParameterCF, val = 0.303
# L2-error=velocity =  0.003133588937449238
# L2-error=pressure =  0.024147756842872438
# t= ParameterCF, val = 0.304
# L2-error=velocity =  0.0031326090034864544
# L2-error=pressure =  0.024135025572763594
# t= ParameterCF, val = 0.305
# L2-error=velocity =  0.0031316252320516724
# L2-error=pressure =  0.02412225739920881
# t= ParameterCF, val = 0.306
# L2-error=velocity =  0.0031306376296549613
# L2-error=pressure =  0.02410945237160547
# t= ParameterCF, val = 0.307
# L2-error=velocity =  0.0031296462027530086
# L2-error=pressure =  0.02409661053947945
# t= ParameterCF, val = 0.308
# L2-error=velocity =  0.0031286509577500756
# L2-error=pressure =  0.024083731952473354
# t= ParameterCF, val = 0.309
# L2-error=velocity =  0.003127651900998652
# L2-error=pressure =  0.024070816660351223
# t= ParameterCF, val = 0.31
# L2-error=velocity =  0.0031266490388003657
# L2-error=pressure =  0.024057864712997878
# t= ParameterCF, val = 0.311
# L2-error=velocity =  0.0031256423774066373
# L2-error=pressure =  0.024044876160424826
# t= ParameterCF, val = 0.312
# L2-error=velocity =  0.003124631923019466
# L2-error=pressure =  0.02403185105275631
# t= ParameterCF, val = 0.313
# L2-error=velocity =  0.0031236176817922012
# L2-error=pressure =  0.024018789440242574
# t= ParameterCF, val = 0.314
# L2-error=velocity =  0.0031225996598302536
# L2-error=pressure =  0.02400569137325868
# t= ParameterCF, val = 0.315
# L2-error=velocity =  0.003121577863191762
# L2-error=pressure =  0.02399255690229577
# t= ParameterCF, val = 0.316
# L2-error=velocity =  0.003120552297888442
# L2-error=pressure =  0.02397938607796927
# t= ParameterCF, val = 0.317
# L2-error=velocity =  0.0031195229698861137
# L2-error=pressure =  0.02396617895101834
# t= ParameterCF, val = 0.318
# L2-error=velocity =  0.003118489885105511
# L2-error=pressure =  0.023952935572301742
# t= ParameterCF, val = 0.319
# L2-error=velocity =  0.0031174530494229476
# L2-error=pressure =  0.023939655992798806
# t= ParameterCF, val = 0.32
# L2-error=velocity =  0.0031164124686709252
# L2-error=pressure =  0.023926340263615016
# t= ParameterCF, val = 0.321
# L2-error=velocity =  0.0031153681486388364
# L2-error=pressure =  0.02391298843597487
# t= ParameterCF, val = 0.322
# L2-error=velocity =  0.0031143200950736138
# L2-error=pressure =  0.02389960056122574
# t= ParameterCF, val = 0.323
# L2-error=velocity =  0.0031132683136803774
# L2-error=pressure =  0.02388617669083794
# t= ParameterCF, val = 0.324
# L2-error=velocity =  0.0031122128101230603
# L2-error=pressure =  0.023872716876403775
# t= ParameterCF, val = 0.325
# L2-error=velocity =  0.0031111535900250234
# L2-error=pressure =  0.023859221169636888
# t= ParameterCF, val = 0.326
# L2-error=velocity =  0.003110090658969639
# L2-error=pressure =  0.023845689622372
# t= ParameterCF, val = 0.327
# L2-error=velocity =  0.0031090240225009618
# L2-error=pressure =  0.023832122286568398
# t= ParameterCF, val = 0.328
# L2-error=velocity =  0.0031079536861242612
# L2-error=pressure =  0.023818519214308834
# t= ParameterCF, val = 0.329
# L2-error=velocity =  0.0031068796553066877
# L2-error=pressure =  0.02380488045779369
# t= ParameterCF, val = 0.33
# L2-error=velocity =  0.0031058019354777704
# L2-error=pressure =  0.023791206069347464
# t= ParameterCF, val = 0.331
# L2-error=velocity =  0.0031047205320300273
# L2-error=pressure =  0.02377749610141856
# t= ParameterCF, val = 0.332
# L2-error=velocity =  0.0031036354503195217
# L2-error=pressure =  0.02376375060657613
# t= ParameterCF, val = 0.333
# L2-error=velocity =  0.003102546695666386
# L2-error=pressure =  0.02374996963751064
# t= ParameterCF, val = 0.334
# L2-error=velocity =  0.003101454273355441
# L2-error=pressure =  0.023736153247034483
# t= ParameterCF, val = 0.335
# L2-error=velocity =  0.003100358188636697
# L2-error=pressure =  0.02372230148808442
# t= ParameterCF, val = 0.336
# L2-error=velocity =  0.0030992584467258704
# L2-error=pressure =  0.023708414413716013
# t= ParameterCF, val = 0.337
# L2-error=velocity =  0.0030981550528048846
# L2-error=pressure =  0.023694492077108324
# t= ParameterCF, val = 0.338
# L2-error=velocity =  0.003097048012022454
# L2-error=pressure =  0.023680534531560046
# t= ParameterCF, val = 0.339
# L2-error=velocity =  0.003095937329494554
# L2-error=pressure =  0.02366654183049738
# t= ParameterCF, val = 0.34
# L2-error=velocity =  0.0030948230103049136
# L2-error=pressure =  0.023652514027461168
# t= ParameterCF, val = 0.341
# L2-error=velocity =  0.003093705059505594
# L2-error=pressure =  0.02363845117611787
# t= ParameterCF, val = 0.342
# L2-error=velocity =  0.003092583482117322
# L2-error=pressure =  0.02362435333025401
# t= ParameterCF, val = 0.343
# L2-error=velocity =  0.0030914582831300923
# L2-error=pressure =  0.023610220543777247
# t= ParameterCF, val = 0.344
# L2-error=velocity =  0.003090329467503611
# L2-error=pressure =  0.02359605287071728
# t= ParameterCF, val = 0.345
# L2-error=velocity =  0.0030891970401677434
# L2-error=pressure =  0.023581850365225407
# t= ParameterCF, val = 0.346
# L2-error=velocity =  0.003088061006023018
# L2-error=pressure =  0.023567613081573024
# t= ParameterCF, val = 0.347
# L2-error=velocity =  0.0030869213699410277
# L2-error=pressure =  0.023553341074152488
# t= ParameterCF, val = 0.348
# L2-error=velocity =  0.003085778136764931
# L2-error=pressure =  0.02353903439747766
# t= ParameterCF, val = 0.349
# L2-error=velocity =  0.003084631311309845
# L2-error=pressure =  0.0235246931061827
# t= ParameterCF, val = 0.35
# L2-error=velocity =  0.003083480898363315
# L2-error=pressure =  0.023510317255022273
# t= ParameterCF, val = 0.351
# L2-error=velocity =  0.003082326902685761
# L2-error=pressure =  0.02349590689887295
# t= ParameterCF, val = 0.352
# L2-error=velocity =  0.0030811693290108077
# L2-error=pressure =  0.02348146209272972
# t= ParameterCF, val = 0.353
# L2-error=velocity =  0.003080008182045832
# L2-error=pressure =  0.023466982891707937
# t= ParameterCF, val = 0.354
# L2-error=velocity =  0.003078843466472275
# L2-error=pressure =  0.023452469351046442
# t= ParameterCF, val = 0.355
# L2-error=velocity =  0.003077675186946127
# L2-error=pressure =  0.023437921526098658
# t= ParameterCF, val = 0.356
# L2-error=velocity =  0.0030765033480982507
# L2-error=pressure =  0.02342333947234297
# t= ParameterCF, val = 0.357
# L2-error=velocity =  0.003075327954534815
# L2-error=pressure =  0.023408723245372964
# t= ParameterCF, val = 0.358
# L2-error=velocity =  0.0030741490108376927
# L2-error=pressure =  0.02339407290090754
# t= ParameterCF, val = 0.359
# L2-error=velocity =  0.0030729665215648554
# L2-error=pressure =  0.02337938849477725
# t= ParameterCF, val = 0.36
# L2-error=velocity =  0.003071780491250694
# L2-error=pressure =  0.023364670082939396
# t= ParameterCF, val = 0.361
# L2-error=velocity =  0.003070590924406454
# L2-error=pressure =  0.02334991772146702
# t= ParameterCF, val = 0.362
# L2-error=velocity =  0.003069397825520563
# L2-error=pressure =  0.023335131466550814
# t= ParameterCF, val = 0.363
# L2-error=velocity =  0.0030682011990590284
# L2-error=pressure =  0.02332031137450249
# t= ParameterCF, val = 0.364
# L2-error=velocity =  0.0030670010494657815
# L2-error=pressure =  0.023305457501752395
# t= ParameterCF, val = 0.365
# L2-error=velocity =  0.0030657973811630238
# L2-error=pressure =  0.023290569904848443
# t= ParameterCF, val = 0.366
# L2-error=velocity =  0.0030645901985515782
# L2-error=pressure =  0.02327564864045607
# t= ParameterCF, val = 0.367
# L2-error=velocity =  0.003063379506011236
# L2-error=pressure =  0.02326069376536259
# t= ParameterCF, val = 0.368
# L2-error=velocity =  0.0030621653079011078
# L2-error=pressure =  0.02324570533646804
# t= ParameterCF, val = 0.369
# L2-error=velocity =  0.0030609476085599217
# L2-error=pressure =  0.023230683410794196
# t= ParameterCF, val = 0.37
# L2-error=velocity =  0.003059726412306384
# L2-error=pressure =  0.02321562804547839
# t= ParameterCF, val = 0.371
# L2-error=velocity =  0.003058501723439492
# L2-error=pressure =  0.023200539297776913
# t= ParameterCF, val = 0.372
# L2-error=velocity =  0.0030572735462388793
# L2-error=pressure =  0.023185417225061695
# t= ParameterCF, val = 0.373
# L2-error=velocity =  0.0030560418849651023
# L2-error=pressure =  0.023170261884824083
# t= ParameterCF, val = 0.374
# L2-error=velocity =  0.0030548067438599703
# L2-error=pressure =  0.023155073334668045
# t= ParameterCF, val = 0.375
# L2-error=velocity =  0.0030535681271468182
# L2-error=pressure =  0.02313985163231882
# t= ParameterCF, val = 0.376
# L2-error=velocity =  0.0030523260390308725
# L2-error=pressure =  0.02312459683561715
# t= ParameterCF, val = 0.377
# L2-error=velocity =  0.0030510804836994926
# L2-error=pressure =  0.02310930900251811
# t= ParameterCF, val = 0.378
# L2-error=velocity =  0.0030498314653225095
# L2-error=pressure =  0.023093988191093543
# t= ParameterCF, val = 0.379
# L2-error=velocity =  0.00304857898805245
# L2-error=pressure =  0.02307863445953256
# t= ParameterCF, val = 0.38
# L2-error=velocity =  0.003047323056024909
# L2-error=pressure =  0.02306324786613895
# t= ParameterCF, val = 0.381
# L2-error=velocity =  0.0030460636733587658
# L2-error=pressure =  0.023047828469331063
# t= ParameterCF, val = 0.382
# L2-error=velocity =  0.0030448008441565175
# L2-error=pressure =  0.0230323763276457
# t= ParameterCF, val = 0.383
# L2-error=velocity =  0.0030435345725045152
# L2-error=pressure =  0.0230168914997309
# t= ParameterCF, val = 0.384
# L2-error=velocity =  0.003042264862473255
# L2-error=pressure =  0.02300137404435214
# t= ParameterCF, val = 0.385
# L2-error=velocity =  0.003040991718117621
# L2-error=pressure =  0.022985824020388113
# t= ParameterCF, val = 0.386
# L2-error=velocity =  0.0030397151434771613
# L2-error=pressure =  0.022970241486833874
# t= ParameterCF, val = 0.387
# L2-error=velocity =  0.003038435142576369
# L2-error=pressure =  0.02295462650279646
# t= ParameterCF, val = 0.388
# L2-error=velocity =  0.003037151719424928
# L2-error=pressure =  0.022938979127498878
# t= ParameterCF, val = 0.389
# L2-error=velocity =  0.00303586487801796
# L2-error=pressure =  0.02292329942027577
# t= ParameterCF, val = 0.39
# L2-error=velocity =  0.0030345746223362498
# L2-error=pressure =  0.022907587440576745
# t= ParameterCF, val = 0.391
# L2-error=velocity =  0.0030332809563465403
# L2-error=pressure =  0.022891843247966257
# t= ParameterCF, val = 0.392
# L2-error=velocity =  0.003031983884001733
# L2-error=pressure =  0.022876066902118804
# t= ParameterCF, val = 0.393
# L2-error=velocity =  0.003030683409241196
# L2-error=pressure =  0.022860258462823205
# t= ParameterCF, val = 0.394
# L2-error=velocity =  0.00302937953599089
# L2-error=pressure =  0.022844417989981457
# t= ParameterCF, val = 0.395
# L2-error=velocity =  0.0030280722681636976
# L2-error=pressure =  0.022828545543608376
# t= ParameterCF, val = 0.396
# L2-error=velocity =  0.0030267616096596034
# L2-error=pressure =  0.02281264118382891
# t= ParameterCF, val = 0.397
# L2-error=velocity =  0.003025447564365972
# L2-error=pressure =  0.02279670497088233
# t= ParameterCF, val = 0.398
# L2-error=velocity =  0.003024130136157678
# L2-error=pressure =  0.022780736965116746
# t= ParameterCF, val = 0.399
# L2-error=velocity =  0.003022809328897423
# L2-error=pressure =  0.02276473722699477
# t= ParameterCF, val = 0.4
# L2-error=velocity =  0.003021485146435881
# L2-error=pressure =  0.022748705817092124
# t= ParameterCF, val = 0.401
# L2-error=velocity =  0.003020157592611979
# L2-error=pressure =  0.022732642796087093
# t= ParameterCF, val = 0.402
# L2-error=velocity =  0.003018826671253067
# L2-error=pressure =  0.022716548224779406
# t= ParameterCF, val = 0.403
# L2-error=velocity =  0.003017492386175103
# L2-error=pressure =  0.022700422164070772
# t= ParameterCF, val = 0.404
# L2-error=velocity =  0.00301615474118292
# L2-error=pressure =  0.022684264674977434
# t= ParameterCF, val = 0.405
# L2-error=velocity =  0.0030148137400703794
# L2-error=pressure =  0.022668075818626746
# t= ParameterCF, val = 0.406
# L2-error=velocity =  0.003013469386620614
# L2-error=pressure =  0.022651855656252037
# t= ParameterCF, val = 0.407
# L2-error=velocity =  0.003012121684606192
# L2-error=pressure =  0.0226356042491998
# t= ParameterCF, val = 0.408
# L2-error=velocity =  0.0030107706377893026
# L2-error=pressure =  0.022619321658923462
# t= ParameterCF, val = 0.409
# L2-error=velocity =  0.003009416249921957
# L2-error=pressure =  0.02260300794698637
# t= ParameterCF, val = 0.41
# L2-error=velocity =  0.0030080585247462114
# L2-error=pressure =  0.022586663175062017
# t= ParameterCF, val = 0.411
# L2-error=velocity =  0.003006697465994325
# L2-error=pressure =  0.022570287404929286
# t= ParameterCF, val = 0.412
# L2-error=velocity =  0.003005333077388941
# L2-error=pressure =  0.022553880698478655
# t= ParameterCF, val = 0.413
# L2-error=velocity =  0.0030039653626432595
# L2-error=pressure =  0.022537443117706335
# t= ParameterCF, val = 0.414
# L2-error=velocity =  0.0030025943254612425
# L2-error=pressure =  0.02252097472471901
# t= ParameterCF, val = 0.415
# L2-error=velocity =  0.0030012199695377655
# L2-error=pressure =  0.02250447558172775
# t= ParameterCF, val = 0.416
# L2-error=velocity =  0.002999842298558816
# L2-error=pressure =  0.022487945751052455
# t= ParameterCF, val = 0.417
# L2-error=velocity =  0.0029984613162016374
# L2-error=pressure =  0.02247138529512052
# t= ParameterCF, val = 0.418
# L2-error=velocity =  0.0029970770261349283
# L2-error=pressure =  0.022454794276466364
# t= ParameterCF, val = 0.419
# L2-error=velocity =  0.002995689432018974
# L2-error=pressure =  0.02243817275772824
# t= ParameterCF, val = 0.42
# L2-error=velocity =  0.002994298537505857
# L2-error=pressure =  0.02242152080165353
# t= ParameterCF, val = 0.421
# L2-error=velocity =  0.002992904346239538
# L2-error=pressure =  0.02240483847109513
# t= ParameterCF, val = 0.422
# L2-error=velocity =  0.0029915068618561118
# L2-error=pressure =  0.022388125829010327
# t= ParameterCF, val = 0.423
# L2-error=velocity =  0.0029901060879838925
# L2-error=pressure =  0.022371382938462206
# t= ParameterCF, val = 0.424
# L2-error=velocity =  0.002988702028243622
# L2-error=pressure =  0.022354609862620764
# t= ParameterCF, val = 0.425
# L2-error=velocity =  0.0029872946862485802
# L2-error=pressure =  0.02233780666475844
# t= ParameterCF, val = 0.426
# L2-error=velocity =  0.0029858840656047762
# L2-error=pressure =  0.02232097340825376
# t= ParameterCF, val = 0.427
# L2-error=velocity =  0.002984470169911045
# L2-error=pressure =  0.02230411015658979
# t= ParameterCF, val = 0.428
# ...
# L2-error=pressure =  0.013229638594692405
# t= ParameterCF, val = 0.858
# L2-error=velocity =  0.0021164465592116476
# L2-error=pressure =  0.013206661206848333
# t= ParameterCF, val = 0.859
# L2-error=velocity =  0.0021139415992905853
# L2-error=pressure =  0.013183686183416645
# t= ParameterCF, val = 0.86
# L2-error=velocity =  0.0021114348813563123
# L2-error=pressure =  0.013160713597284409
# t= ParameterCF, val = 0.861
# L2-error=velocity =  0.002108926408969663
# L2-error=pressure =  0.013137743521255503
# t= ParameterCF, val = 0.862
# L2-error=velocity =  0.002106416185690415
# L2-error=pressure =  0.013114776028053648
# t= ParameterCF, val = 0.863
# L2-error=velocity =  0.0021039042150772986
# L2-error=pressure =  0.013091811190316455
# t= ParameterCF, val = 0.864
# L2-error=velocity =  0.0021013905006879267
# L2-error=pressure =  0.013068849080599859
# t= ParameterCF, val = 0.865
# L2-error=velocity =  0.0020988750460788335
# L2-error=pressure =  0.01304588977137513
# t= ParameterCF, val = 0.866
# L2-error=velocity =  0.002096357854805464
# L2-error=pressure =  0.013022933335029392
# t= ParameterCF, val = 0.867
# L2-error=velocity =  0.002093838930422115
# L2-error=pressure =  0.012999979843862452
# t= ParameterCF, val = 0.868
# L2-error=velocity =  0.0020913182764819714
# L2-error=pressure =  0.01297702937009039
# t= ParameterCF, val = 0.869
# L2-error=velocity =  0.0020887958965370933
# L2-error=pressure =  0.012954081985839843
# t= ParameterCF, val = 0.87
# L2-error=velocity =  0.002086271794138392
# L2-error=pressure =  0.01293113776315384
# t= ParameterCF, val = 0.871
# L2-error=velocity =  0.0020837459728355865
# L2-error=pressure =  0.0129081967739859
# t= ParameterCF, val = 0.872
# L2-error=velocity =  0.002081218436177251
# L2-error=pressure =  0.012885259090199962
# t= ParameterCF, val = 0.873
# L2-error=velocity =  0.0020786891877107834
# L2-error=pressure =  0.012862324783572623
# t= ParameterCF, val = 0.874
# L2-error=velocity =  0.002076158230982388
# L2-error=pressure =  0.012839393925790666
# t= ParameterCF, val = 0.875
# L2-error=velocity =  0.0020736255695370472
# L2-error=pressure =  0.012816466588450601
# t= ParameterCF, val = 0.876
# L2-error=velocity =  0.0020710912069185463
# L2-error=pressure =  0.012793542843058543
# t= ParameterCF, val = 0.877
# L2-error=velocity =  0.0020685551466694367
# L2-error=pressure =  0.012770622761028569
# t= ParameterCF, val = 0.878
# L2-error=velocity =  0.002066017392331063
# L2-error=pressure =  0.012747706413683432
# t= ParameterCF, val = 0.879
# L2-error=velocity =  0.00206347794744348
# L2-error=pressure =  0.012724793872253656
# t= ParameterCF, val = 0.88
# L2-error=velocity =  0.0020609368155455124
# L2-error=pressure =  0.01270188520787538
# t= ParameterCF, val = 0.881
# L2-error=velocity =  0.0020583940001747316
# L2-error=pressure =  0.012678980491593026
# t= ParameterCF, val = 0.882
# L2-error=velocity =  0.0020558495048673855
# L2-error=pressure =  0.012656079794354872
# t= ParameterCF, val = 0.883
# L2-error=velocity =  0.0020533033331584893
# L2-error=pressure =  0.012633183187016088
# t= ParameterCF, val = 0.884
# L2-error=velocity =  0.0020507554885817333
# L2-error=pressure =  0.012610290740334963
# t= ParameterCF, val = 0.885
# L2-error=velocity =  0.002048205974669483
# L2-error=pressure =  0.012587402524973671
# t= ParameterCF, val = 0.886
# L2-error=velocity =  0.0020456547949528315
# L2-error=pressure =  0.012564518611498472
# t= ParameterCF, val = 0.887
# L2-error=velocity =  0.0020431019529614813
# L2-error=pressure =  0.012541639070379295
# t= ParameterCF, val = 0.888
# L2-error=velocity =  0.002040547452223853
# L2-error=pressure =  0.012518763971985581
# t= ParameterCF, val = 0.889
# L2-error=velocity =  0.0020379912962669882
# L2-error=pressure =  0.012495893386589995
# t= ParameterCF, val = 0.89
# L2-error=velocity =  0.002035433488616584
# L2-error=pressure =  0.012473027384366906
# t= ParameterCF, val = 0.891
# L2-error=velocity =  0.002032874032796968
# L2-error=pressure =  0.012450166035388777
# t= ParameterCF, val = 0.892
# L2-error=velocity =  0.002030312932331046
# L2-error=pressure =  0.01242730940962964
# t= ParameterCF, val = 0.893
# L2-error=velocity =  0.0020277501907403923
# L2-error=pressure =  0.012404457576961425
# t= ParameterCF, val = 0.894
# L2-error=velocity =  0.002025185811545162
# L2-error=pressure =  0.012381610607156689
# t= ParameterCF, val = 0.895
# L2-error=velocity =  0.002022619798264077
# L2-error=pressure =  0.012358768569882318
# t= ParameterCF, val = 0.896
# L2-error=velocity =  0.0020200521544144704
# L2-error=pressure =  0.012335931534706204
# t= ParameterCF, val = 0.897
# L2-error=velocity =  0.0020174828835122175
# L2-error=pressure =  0.012313099571089909
# t= ParameterCF, val = 0.898
# L2-error=velocity =  0.00201491198907179
# L2-error=pressure =  0.012290272748392936
# t= ParameterCF, val = 0.899
# L2-error=velocity =  0.002012339474606179
# L2-error=pressure =  0.012267451135870298
# t= ParameterCF, val = 0.9
# L2-error=velocity =  0.002009765343626913
# L2-error=pressure =  0.012244634802669938
# t= ParameterCF, val = 0.901
# L2-error=velocity =  0.0020071895996441043
# L2-error=pressure =  0.012221823817836883
# t= ParameterCF, val = 0.902
# L2-error=velocity =  0.002004612246166321
# L2-error=pressure =  0.01219901825030734
# t= ParameterCF, val = 0.903
# L2-error=velocity =  0.0020020332867006834
# L2-error=pressure =  0.012176218168911897
# t= ParameterCF, val = 0.904
# L2-error=velocity =  0.0019994527247528047
# L2-error=pressure =  0.012153423642372665
# t= ParameterCF, val = 0.905
# L2-error=velocity =  0.0019968705638267795
# L2-error=pressure =  0.012130634739304874
# t= ParameterCF, val = 0.906
# L2-error=velocity =  0.0019942868074252066
# L2-error=pressure =  0.012107851528212532
# t= ParameterCF, val = 0.907
# L2-error=velocity =  0.001991701459049157
# L2-error=pressure =  0.012085074077493247
# t= ParameterCF, val = 0.908
# L2-error=velocity =  0.001989114522198136
# L2-error=pressure =  0.012062302455432647
# t= ParameterCF, val = 0.909
# L2-error=velocity =  0.001986526000370142
# L2-error=pressure =  0.012039536730205429
# t= ParameterCF, val = 0.91
# L2-error=velocity =  0.0019839358970616073
# L2-error=pressure =  0.012016776969876129
# t= ParameterCF, val = 0.911
# L2-error=velocity =  0.0019813442157673934
# L2-error=pressure =  0.011994023242396673
# t= ParameterCF, val = 0.912
# L2-error=velocity =  0.0019787509599807993
# L2-error=pressure =  0.011971275615606894
# t= ParameterCF, val = 0.913
# L2-error=velocity =  0.001976156133193538
# L2-error=pressure =  0.011948534157232685
# t= ParameterCF, val = 0.914
# L2-error=velocity =  0.001973559738895735
# L2-error=pressure =  0.011925798934888
# t= ParameterCF, val = 0.915
# L2-error=velocity =  0.00197096178057591
# L2-error=pressure =  0.011903070016069542
# t= ParameterCF, val = 0.916
# L2-error=velocity =  0.0019683622617209994
# L2-error=pressure =  0.011880347468160295
# t= ParameterCF, val = 0.917
# L2-error=velocity =  0.001965761185816291
# L2-error=pressure =  0.011857631358428981
# t= ParameterCF, val = 0.918
# L2-error=velocity =  0.001963158556345456
# L2-error=pressure =  0.011834921754026537
# t= ParameterCF, val = 0.919
# L2-error=velocity =  0.001960554376790548
# L2-error=pressure =  0.011812218721986461
# t= ParameterCF, val = 0.92
# L2-error=velocity =  0.0019579486506319525
# L2-error=pressure =  0.011789522329226367
# t= ParameterCF, val = 0.921
# L2-error=velocity =  0.001955341381348411
# L2-error=pressure =  0.011766832642544451
# t= ParameterCF, val = 0.922
# L2-error=velocity =  0.0019527325724170296
# L2-error=pressure =  0.011744149728621225
# t= ParameterCF, val = 0.923
# L2-error=velocity =  0.0019501222273132011
# L2-error=pressure =  0.01172147365401568
# t= ParameterCF, val = 0.924
# L2-error=velocity =  0.001947510349510691
# L2-error=pressure =  0.011698804485169727
# t= ParameterCF, val = 0.925
# L2-error=velocity =  0.001944896942481524
# L2-error=pressure =  0.01167614228840166
# t= ParameterCF, val = 0.926
# L2-error=velocity =  0.0019422820096960743
# L2-error=pressure =  0.01165348712991079
# t= ParameterCF, val = 0.927
# L2-error=velocity =  0.001939665554622986
# L2-error=pressure =  0.011630839075773043
# t= ParameterCF, val = 0.928
# L2-error=velocity =  0.001937047580729214
# L2-error=pressure =  0.011608198191942299
# t= ParameterCF, val = 0.929
# L2-error=velocity =  0.0019344280914799772
# L2-error=pressure =  0.011585564544248831
# t= ParameterCF, val = 0.93
# L2-error=velocity =  0.0019318070903387738
# L2-error=pressure =  0.0115629381983994
# t= ParameterCF, val = 0.931
# L2-error=velocity =  0.001929184580767371
# L2-error=pressure =  0.011540319219977085
# t= ParameterCF, val = 0.932
# L2-error=velocity =  0.0019265605662257743
# L2-error=pressure =  0.01151770767443776
# t= ParameterCF, val = 0.933
# L2-error=velocity =  0.0019239350501722673
# L2-error=pressure =  0.011495103627112969
# t= ParameterCF, val = 0.934
# L2-error=velocity =  0.0019213080360633572
# L2-error=pressure =  0.011472507143207883
# t= ParameterCF, val = 0.935
# L2-error=velocity =  0.0019186795273537687
# L2-error=pressure =  0.011449918287800289
# t= ParameterCF, val = 0.936
# L2-error=velocity =  0.0019160495274964796
# L2-error=pressure =  0.011427337125840918
# t= ParameterCF, val = 0.937
# L2-error=velocity =  0.0019134180399426656
# L2-error=pressure =  0.011404763722150388
# t= ParameterCF, val = 0.938
# L2-error=velocity =  0.001910785068141707
# L2-error=pressure =  0.011382198141422675
# t= ParameterCF, val = 0.939
# L2-error=velocity =  0.0019081506155412087
# L2-error=pressure =  0.011359640448220033
# t= ParameterCF, val = 0.94
# L2-error=velocity =  0.001905514685586957
# L2-error=pressure =  0.01133709070697648
# t= ParameterCF, val = 0.941
# L2-error=velocity =  0.0019028772817229309
# L2-error=pressure =  0.011314548981992821
# t= ParameterCF, val = 0.942
# L2-error=velocity =  0.0019002384073912749
# L2-error=pressure =  0.011292015337441067
# t= ParameterCF, val = 0.943
# L2-error=velocity =  0.001897598066032298
# L2-error=pressure =  0.011269489837358579
# t= ParameterCF, val = 0.944
# L2-error=velocity =  0.001894956261084526
# L2-error=pressure =  0.011246972545650909
# t= ParameterCF, val = 0.945
# L2-error=velocity =  0.0018923129959845836
# L2-error=pressure =  0.01122446352609031
# t= ParameterCF, val = 0.946
# L2-error=velocity =  0.0018896682741672741
# L2-error=pressure =  0.011201962842314343
# t= ParameterCF, val = 0.947
# L2-error=velocity =  0.0018870220990655385
# L2-error=pressure =  0.011179470557826482
# t= ParameterCF, val = 0.948
# L2-error=velocity =  0.0018843744741104604
# L2-error=pressure =  0.011156986735994448
# t= ParameterCF, val = 0.949
# L2-error=velocity =  0.0018817254027312356
# L2-error=pressure =  0.011134511440049366
# t= ParameterCF, val = 0.95
# L2-error=velocity =  0.001879074888355194
# L2-error=pressure =  0.011112044733086524
# t= ParameterCF, val = 0.951
# L2-error=velocity =  0.001876422934407782
# L2-error=pressure =  0.011089586678062624
# t= ParameterCF, val = 0.952
# L2-error=velocity =  0.00187376954431256
# L2-error=pressure =  0.011067137337797855
# t= ParameterCF, val = 0.953
# L2-error=velocity =  0.001871114721491173
# L2-error=pressure =  0.011044696774972109
# t= ParameterCF, val = 0.954
# L2-error=velocity =  0.0018684584693633697
# L2-error=pressure =  0.011022265052127254
# t= ParameterCF, val = 0.955
# L2-error=velocity =  0.0018658007913469959
# L2-error=pressure =  0.010999842231664099
# t= ParameterCF, val = 0.956
# L2-error=velocity =  0.0018631416908579542
# L2-error=pressure =  0.010977428375844632
# t= ParameterCF, val = 0.957
# L2-error=velocity =  0.0018604811713102737
# L2-error=pressure =  0.010955023546786303
# t= ParameterCF, val = 0.958
# L2-error=velocity =  0.0018578192361160054
# L2-error=pressure =  0.010932627806468016
# t= ParameterCF, val = 0.959
# L2-error=velocity =  0.0018551558886852882
# L2-error=pressure =  0.010910241216723652
# t= ParameterCF, val = 0.96
# L2-error=velocity =  0.0018524911324263
# L2-error=pressure =  0.010887863839244713
# t= ParameterCF, val = 0.961
# L2-error=velocity =  0.0018498249707452898
# L2-error=pressure =  0.010865495735578795
# t= ParameterCF, val = 0.962
# L2-error=velocity =  0.0018471574070465437
# L2-error=pressure =  0.010843136967129168
# t= ParameterCF, val = 0.963
# L2-error=velocity =  0.0018444884447323764
# L2-error=pressure =  0.010820787595152122
# t= ParameterCF, val = 0.964
# L2-error=velocity =  0.0018418180872031506
# L2-error=pressure =  0.01079844768076049
# t= ParameterCF, val = 0.965
# L2-error=velocity =  0.0018391463378572602
# L2-error=pressure =  0.010776117284918122
# t= ParameterCF, val = 0.966
# L2-error=velocity =  0.0018364732000911038
# L2-error=pressure =  0.01075379646844433
# t= ParameterCF, val = 0.967
# L2-error=velocity =  0.001833798677299098
# L2-error=pressure =  0.010731485292007646
# t= ParameterCF, val = 0.968
# L2-error=velocity =  0.001831122772873696
# L2-error=pressure =  0.010709183816129857
# t= ParameterCF, val = 0.969
# L2-error=velocity =  0.0018284454902053324
# L2-error=pressure =  0.010686892101182479
# t= ParameterCF, val = 0.97
# L2-error=velocity =  0.0018257668326824312
# L2-error=pressure =  0.010664610207386772
# t= ParameterCF, val = 0.971
# L2-error=velocity =  0.0018230868036914483
# L2-error=pressure =  0.010642338194815887
# t= ParameterCF, val = 0.972
# L2-error=velocity =  0.0018204054066168016
# L2-error=pressure =  0.01062007612338875
# t= ParameterCF, val = 0.973
# L2-error=velocity =  0.0018177226448408905
# L2-error=pressure =  0.010597824052874098
# t= ParameterCF, val = 0.974
# L2-error=velocity =  0.0018150385217441207
# L2-error=pressure =  0.010575582042886092
# t= ParameterCF, val = 0.975
# L2-error=velocity =  0.0018123530407048326
# L2-error=pressure =  0.010553350152888639
# t= ParameterCF, val = 0.976
# L2-error=velocity =  0.001809666205099376
# L2-error=pressure =  0.010531128442190108
# t= ParameterCF, val = 0.977
# L2-error=velocity =  0.0018069780183020353
# L2-error=pressure =  0.010508916969942588
# t= ParameterCF, val = 0.978
# L2-error=velocity =  0.0018042884836850616
# L2-error=pressure =  0.010486715795145629
# t= ParameterCF, val = 0.979
# L2-error=velocity =  0.001801597604618669
# L2-error=pressure =  0.010464524976641788
# t= ParameterCF, val = 0.98
# L2-error=velocity =  0.0017989053844710279
# L2-error=pressure =  0.010442344573115063
# t= ParameterCF, val = 0.981
# L2-error=velocity =  0.0017962118266082437
# L2-error=pressure =  0.010420174643096195
# t= ParameterCF, val = 0.982
# L2-error=velocity =  0.0017935169343943622
# L2-error=pressure =  0.01039801524495436
# t= ParameterCF, val = 0.983
# L2-error=velocity =  0.0017908207111913663
# L2-error=pressure =  0.010375866436901696
# t= ParameterCF, val = 0.984
# L2-error=velocity =  0.0017881231603591814
# L2-error=pressure =  0.010353728276990118
# t= ParameterCF, val = 0.985
# L2-error=velocity =  0.00178542428525565
# L2-error=pressure =  0.010331600823112607
# t= ParameterCF, val = 0.986
# L2-error=velocity =  0.0017827240892365553
# L2-error=pressure =  0.01030948413300045
# t= ParameterCF, val = 0.987
# L2-error=velocity =  0.001780022575655594
# L2-error=pressure =  0.010287378264223782
# t= ParameterCF, val = 0.988
# L2-error=velocity =  0.001777319747864376
# L2-error=pressure =  0.010265283274191109
# t= ParameterCF, val = 0.989
# L2-error=velocity =  0.001774615609212426
# L2-error=pressure =  0.010243199220147697
# t= ParameterCF, val = 0.99
# L2-error=velocity =  0.0017719101630471812
# L2-error=pressure =  0.01022112615917569
# t= ParameterCF, val = 0.991
# L2-error=velocity =  0.0017692034127139938
# L2-error=pressure =  0.010199064148192742
# t= ParameterCF, val = 0.992
# L2-error=velocity =  0.0017664953615561126
# L2-error=pressure =  0.010177013243952027
# t= ParameterCF, val = 0.993
# L2-error=velocity =  0.001763786012914671
# L2-error=pressure =  0.010154973503041327
# t= ParameterCF, val = 0.994
# L2-error=velocity =  0.001761075370128722
# L2-error=pressure =  0.01013294498188182
# t= ParameterCF, val = 0.995
# L2-error=velocity =  0.0017583634365351995
# L2-error=pressure =  0.010110927736728278
# t= ParameterCF, val = 0.996
# L2-error=velocity =  0.0017556502154689308
# L2-error=pressure =  0.01008892182366735
# t= ParameterCF, val = 0.997
# L2-error=velocity =  0.0017529357102626449
# L2-error=pressure =  0.010066927298618356
# t= ParameterCF, val = 0.998
# L2-error=velocity =  0.0017502199242469233
# L2-error=pressure =  0.010044944217331838
# t= ParameterCF, val = 0.999
# L2-error=velocity =  0.001747502860750249
# L2-error=pressure =  0.010022972635385803

# %%
Draw (gfut.components[0], mesh, interpolate_multidim=True, animate=True,
      min=-0.1, max=0.1, autoscale=False, vectors = True)
Draw (gfut.components[1], mesh, interpolate_multidim=True, animate=True,
      min=-0.5, max=0.5, autoscale=False)
# Out:
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# WebGuiWidget(layout=Layout(height='50vh', width='100%'), value={'gui_settings': {}, 'ngsolve_version': '6.2.23…
# BaseWebGuiScene

# %%
maxhs  = [0.2,0.1,0.05] 
err_v =  [0.25180908428244286,0.06042844667099612 ]
err_p = [ 0.05064082177944421,0.007755257351949141  ] 
#err_v =  [0.0101407566076981,0.001747502860750249,0.00044342729502770646 ]
#err_p = [0.027880013901244633,0.010022972635385803,0.006682130004079638 ]

# %%
eoc = [ log(err_v[i-1]/err_v[i])/log(2) for i in range(1,len(err_v))]
print("eoc = ", eoc)
# Out:
# eoc =  [2.059030567990694]

# %% [markdown]
# In this benchmark scenario of specific interests are the forces acting on the disk (cylinder). We will discuss how to compute them next.
